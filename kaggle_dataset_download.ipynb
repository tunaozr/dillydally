# %% [markdown]
# <a href="https://colab.research.google.com/github/tunaozr/dillydally/blob/main/kaggle_dataset_download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-7c311203-b2de-4033-84ea-2bbf8d2733eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c311203-b2de-4033-84ea-2bbf8d2733eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir ~/.kaggle

# %%
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/kaggle.json

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download sshikamaru/car-object-detection
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sshikamaru/car-object-detection
# License(s): other
# ...
#  85% 95.0M/112M [00:00<00:00, 144MB/s]
# 100% 112M/112M [00:00<00:00, 122MB/s]

# %%
# !unzip car-object-detection.zip -d /content/drive/MyDrive/
# Out:
# Archive:  car-object-detection.zip
# replace /content/drive/MyDrive/data/sample_submission.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace /content/drive/MyDrive/data/testing_images/vid_5_25100.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: a
# error:  invalid response [a]
# replace /content/drive/MyDrive/data/testing_images/vid_5_25100.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/drive/MyDrive/data/testing_images/vid_5_25100.jpg
#   inflating: /content/drive/MyDrive/data/testing_images/vid_5_25120.jpg
#   inflating: /content/drive/MyDrive/data/testing_images/vid_5_25140.jpg
#   inflating: /content/drive/MyDrive/data/testing_images/vid_5_25160.jpg
#   inflating: /content/drive/MyDrive/data/testing_images/vid_5_25180.jpg
#   inflating: /content/drive/MyDrive/data/testing_images/vid_5_25200.jpg
#   inflating: /content/drive/MyDrive/data/testing_images/vid_5_25220.jpg
#   inflating: /content/drive/MyDrive/data/testing_images/vid_5_25240.jpg
# ...
